# %%
import pandas as pd
import numpy as np
warrior2_left = pd.read_csv('../warrior2left_iyengar.csv')

# %%
warrior2_left.head()
warrior2_left.loc[:,'pose'] = pd.Series(np.ones(length+1),index=warrior2_left.index)

# %%
#
warrior2_lefttest=warrior2_left.drop(['pose'])
warrior2_lefttest
# Out:
#             a1          a2          a3          a4          a5         a6  \
# 0   179.329727  178.046637  108.715396  178.520223  124.288191  95.180166
# 1   176.714314  175.499523  106.324653  179.923475  125.399895  92.036996
# 2   177.364444  178.433315  107.178170  179.996919  126.162403  93.645470
# 3   179.000915  178.530366  105.766290  178.004125  122.455435  94.746409
# 4   178.532037  177.141720  106.281353  177.560606  122.560431  92.865525
# 5   177.951023  177.304401  106.058632  178.137028  122.571331  92.023814
# 6   179.663008  178.561692  104.617989  178.317397  125.271334  94.847088
# 7   179.936837  175.529557  106.342571  179.220707  124.679809  92.839938
# 8   176.288168  178.619706  105.410657  179.957339  123.192380  93.609869
# 9   176.762542  179.978706  101.120078  179.994591  123.936602  89.318325
# 10  175.564240  177.111902  103.257926  179.557564  123.023260  92.362076
# 11  178.943969  177.143149  109.019887  178.512745  125.887450  93.045779
# ...
